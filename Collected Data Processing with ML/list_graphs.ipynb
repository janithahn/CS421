# %%
import pandas as pd

# %%
pd.set_option("display.max.columns", None)
df_runtime = pd.read_csv('./data/runtime_10trials_80steps.csv')

# %%
df_runtime.columns = df_runtime.columns.str.replace('NumberOfIntegers', 'NumberOfElements')

# %%
df_runtime
# Out:
#     NumberOfElements  ArrayList_insert()  ArrayList_insertAt()  \
# 0             100000                2.22                  5.78
# 1             125000                1.04                  8.08
# 2             150000                4.78                 11.63
# 3             175000                3.36                 15.25
# 4             200000                3.45                 21.05
# ..               ...                 ...                   ...
# 75           1975000               18.08                965.97
# 76           2000000               27.36                972.83
# 77           2025000               12.58                963.08
# 78           2050000                9.82                971.23
# 79           2075000               11.77                970.62
#
#     ArrayList_searchMethod1()  ArrayList_searchMethod2()  ArrayList_get()  \
# 0                        0.54                       0.54             0.07
# 1                        0.39                       0.39             0.09
# 2                        0.55                       0.54             0.10
# 3                        0.64                       0.62             0.02
# 4                        0.89                       0.91             0.02
# ..                        ...                        ...              ...
# 75                      28.91                      28.62             0.01
# 76                      28.97                      28.86             0.01
# 77                      29.54                      29.28             0.01
# 78                      29.22                      29.05             0.01
# 79                      29.60                      29.40             0.01
#
#     ArrayList_delete()  ArrayList_Initialized_insert()  \
# 0                 5.81                            1.17
# 1                 8.05                            1.00
# 2                11.56                            1.00
# 3                15.45                            2.90
# 4                21.64                            3.45
# ..                 ...                             ...
# 75              969.84                            7.90
# 76              978.06                            7.41
# 77              975.81                           11.07
# 78              979.18                            8.25
# 79              978.33                            9.04
#
#     ArrayList_Initialized_insertAt()  ArrayList_Initialized_searchMethod1()  \
# 0                               5.18                                   0.26
# 1                               8.06                                   0.39
# 2                              11.53                                   0.50
# 3                              15.28                                   0.64
# 4                              21.02                                   0.86
# ..                               ...                                    ...
# 75                            971.71                                  29.50
# 76                            969.01                                  29.78
# 77                            969.58                                  29.24
# 78                            967.23                                  29.53
# 79                            968.29                                  29.34
#
#     ArrayList_Initialized_searchMethod2()  ArrayList_Initialized_get()  \
# 0                                    0.26                         0.10
# 1                                    0.39                         0.09
# 2                                    0.50                         0.03
# 3                                    0.64                         0.02
# 4                                    0.86                         0.00
# ..                                    ...                          ...
# 75                                  29.30                         0.01
# 76                                  29.52                         0.01
# 77                                  29.04                         0.01
# 78                                  29.28                         0.01
# 79                                  29.07                         0.01
#
#     ArrayList_Initialized_delete()  LinkedList_insert()  \
# 0                             5.32                 2.33
# 1                             8.15                 1.05
# 2                            11.76                 0.57
# 3                            15.67                 7.54
# 4                            21.49                 6.50
# ..                             ...                  ...
# 75                          976.62                 6.54
# 76                          979.04                29.36
# 77                          976.42                66.12
# 78                          980.36                15.59
# 79                          966.54                18.27
#
#     LinkedList_insertAt()  LinkedList_searchMethod1()  \
# 0                    0.70                        1.05
# 1                    0.91                        1.28
# 2                    1.34                        1.87
# 3                    1.89                        2.55
# 4                    2.30                        3.28
# ..                    ...                         ...
# 75                  60.60                       89.17
# 76                  60.64                       90.86
# 77                  62.48                       91.76
# 78                  60.90                       92.43
# 79                  60.62                       91.00
#
#     LinkedList_searchMethod2()  LinkedList_get()  LinkedList_delete()  \
# 0                         0.85              0.67                 0.07
# 1                         1.28              0.88                 0.06
# 2                         1.86              1.26                 0.08
# 3                         2.54              1.73                 0.09
# 4                         3.22              2.20                 0.05
# ..                         ...               ...                  ...
# 75                       89.57             59.69                 0.05
# 76                       91.19             59.72                 0.05
# 77                       92.03             60.52                 0.05
# 78                       92.70             59.90                 0.04
# 79                       91.42             59.96                 0.05
#
#     Vector_insert()  Vector_insertAt()  Vector_searchMethod1()  \
# 0              2.92               5.85                    0.50
# 1              0.88               8.29                    0.40
# 2              0.90              11.96                    0.56
# 3              1.32              16.18                    0.67
# 4              1.45              19.86                    0.84
# ..              ...                ...                     ...
# 75             9.21             959.97                   29.62
# 76            13.51             975.94                   30.64
# 77             9.59             969.16                   30.18
# 78            17.12             959.20                   30.21
# 79             9.52             969.35                   30.52
#
#     Vector_searchMethod2()  Vector_get()  Vector_delete()  \
# 0                     0.53          0.08             5.94
# 1                     0.40          0.09             8.40
# 2                     0.56          0.11            12.12
# 3                     0.67          0.02            16.41
# 4                     0.86          0.02            20.10
# ..                     ...           ...              ...
# 75                   29.76          0.02           964.67
# 76                   30.50          0.02           981.59
# 77                   30.02          0.02           977.11
# 78                   29.93          0.02           970.34
# 79                   30.37          0.02           973.18
#
#     Vector_Initialized_insert()  Vector_Initialized_insertAt()  \
# 0                          0.76                           5.13
# 1                          0.91                           8.27
# 2                          1.08                          11.91
# 3                          1.32                          17.80
# 4                          1.39                          19.90
# ..                          ...                            ...
# 75                         7.84                         955.76
# 76                         8.32                         973.40
# 77                         8.51                         976.18
# 78                         7.92                         967.85
# 79                         8.89                         972.11
#
#     Vector_Initialized_searchMethod1()  Vector_Initialized_searchMethod2()  \
# 0                                 0.26                                0.26
# 1                                 0.40                                0.41
# 2                                 0.52                                0.51
# 3                                 0.68                                0.67
# 4                                 0.81                                0.79
# ..                                 ...                                 ...
# 75                               29.41                               29.44
# 76                               30.33                               30.35
# 77                               30.64                               30.38
# 78                               30.36                               30.26
# 79                               30.62                               30.47
#
#     Vector_Initialized_get()  Vector_Initialized_delete()
# 0                       0.07                         5.18
# 1                       0.09                         8.41
# 2                       0.03                        12.03
# 3                       0.02                        16.50
# 4                       0.00                        20.05
# ..                       ...                          ...
# 75                      0.02                       963.53
# 76                      0.02                       978.54
# 77                      0.02                       983.17
# 78                      0.02                       974.15
# 79                      0.02                       976.03
#
# [80 rows x 31 columns]

# %%
df_runtime.iloc[0:38].plot(figsize=(10, 10), x="NumberOfElements", 
        y=[
            # "ArrayList_insert()", 
            "ArrayList_insertAt()", 
            # "ArrayList_searchMethod1()",
            # "ArrayList_searchMethod2()",
            # "ArrayList_get()",
            # "ArrayList_delete()",

            # "ArrayList_Initialized_insert()", 
            "ArrayList_Initialized_insertAt()", 
            # "ArrayList_Initialized_searchMethod1()",
            # "ArrayList_Initialized_searchMethod2()",
            # "ArrayList_Initialized_get()",
            # "ArrayList_Initialized_delete()",
            
            # "LinkedList_insert()", 
            "LinkedList_insertAt()", 
            # "LinkedList_searchMethod1()",
            # "LinkedList_searchMethod2()",
            # "LinkedList_get()",
            # "LinkedList_delete()",
            
            # "Vector_insert()", 
            "Vector_insertAt()", 
            # "Vector_searchMethod1()",
            # "Vector_searchMethod2()",
            # "Vector_get()",
            # "Vector_delete()"

            # "Vector_Initialized_insert()", 
            "Vector_Initialized_insertAt()", 
            # "Vector_Initialized_searchMethod1()",
            # "Vector_Initialized_searchMethod2()",
            # "Vector_Initialized_get()",
            # "Vector_Initialized_delete()"
           ]
        )
# Out:
# <AxesSubplot:xlabel='NumberOfElements'>

# %%
df_memory = pd.read_csv('./data/memory_10trials_80steps.csv')

# %%
df_memory.columns = df_runtime.columns.str.replace('NumberOfIntegers', 'NumberOfElements')

# %%
df_memory
# Out:
#     NumberOfElements  ArrayList_insert()  ArrayList_insertAt()  \
# 0             100000                   3                     3
# 1             125000                   5                     5
# 2             150000                   5                     5
# 3             175000                   6                     6
# 4             200000                   6                     6
# ..               ...                 ...                   ...
# 75           1975000                  27                    27
# 76           2000000                  27                    27
# 77           2025000                  27                    27
# 78           2050000                  27                    27
# 79           2075000                  27                    27
#
#     ArrayList_searchMethod1()  ArrayList_searchMethod2()  ArrayList_get()  \
# 0                           3                          3                3
# 1                           5                          5                5
# 2                           5                          5                5
# 3                           6                          6                6
# 4                           6                          6                6
# ..                        ...                        ...              ...
# 75                         27                         27               27
# 76                         27                         27               27
# 77                         27                         27               27
# 78                         27                         27               27
# 79                         27                         27               27
#
#     ArrayList_delete()  ArrayList_Initialized_insert()  \
# 0                    3                              11
# 1                    5                              12
# 2                    5                              12
# 3                    6                              13
# 4                    6                              13
# ..                 ...                             ...
# 75                  27                              30
# 76                  27                              30
# 77                  27                              30
# 78                  27                              30
# 79                  27                              30
#
#     ArrayList_Initialized_insertAt()  ArrayList_Initialized_searchMethod1()  \
# 0                                 11                                     11
# 1                                 12                                     12
# 2                                 12                                     12
# 3                                 13                                     13
# 4                                 13                                     13
# ..                               ...                                    ...
# 75                                30                                     30
# 76                                30                                     30
# 77                                30                                     30
# 78                                30                                     30
# 79                                30                                     30
#
#     ArrayList_Initialized_searchMethod2()  ArrayList_Initialized_get()  \
# 0                                      11                           11
# 1                                      12                           12
# 2                                      12                           12
# 3                                      13                           13
# 4                                      13                           13
# ..                                    ...                          ...
# 75                                     30                           30
# 76                                     30                           30
# 77                                     30                           30
# 78                                     30                           30
# 79                                     30                           30
#
#     ArrayList_Initialized_delete()  LinkedList_insert()  \
# 0                               11                    5
# 1                               12                    7
# 2                               12                    8
# 3                               13                    9
# 4                               13                   10
# ..                             ...                  ...
# 75                              30                   46
# 76                              30                   46
# 77                              30                   46
# 78                              30                   46
# 79                              30                   46
#
#     LinkedList_insertAt()  LinkedList_searchMethod1()  \
# 0                       5                           5
# 1                       7                           7
# 2                       8                           8
# 3                       9                           9
# 4                      10                          10
# ..                    ...                         ...
# 75                     47                          47
# 76                     47                          47
# 77                     47                          47
# 78                     47                          47
# 79                     47                          47
#
#     LinkedList_searchMethod2()  LinkedList_get()  LinkedList_delete()  \
# 0                            5                 5                    5
# 1                            7                 7                    7
# 2                            8                 8                    8
# 3                            9                 9                    9
# 4                           10                10                   10
# ..                         ...               ...                  ...
# 75                          47                47                   46
# 76                          47                47                   46
# 77                          47                47                   46
# 78                          47                47                   46
# 79                          47                47                   46
#
#     Vector_insert()  Vector_insertAt()  Vector_searchMethod1()  \
# 0                 4                  4                       4
# 1                 5                  5                       5
# 2                 5                  5                       5
# 3                 7                  7                       7
# 4                 7                  7                       7
# ..              ...                ...                     ...
# 75               28                 28                      28
# 76               28                 28                      28
# 77               28                 28                      28
# 78               28                 28                      28
# 79               28                 28                      28
#
#     Vector_searchMethod2()  Vector_get()  Vector_delete()  \
# 0                        4             4                4
# 1                        5             5                5
# 2                        5             5                5
# 3                        7             7                7
# 4                        7             7                7
# ..                     ...           ...              ...
# 75                      28            28               28
# 76                      28            28               28
# 77                      28            28               28
# 78                      28            28               28
# 79                      28            28               28
#
#     Vector_Initialized_insert()  Vector_Initialized_insertAt()  \
# 0                            11                             11
# 1                            12                             12
# 2                            12                             12
# 3                            13                             13
# 4                            13                             13
# ..                          ...                            ...
# 75                           30                             30
# 76                           30                             30
# 77                           30                             30
# 78                           30                             30
# 79                           30                             30
#
#     Vector_Initialized_searchMethod1()  Vector_Initialized_searchMethod2()  \
# 0                                   11                                  11
# 1                                   12                                  12
# 2                                   12                                  12
# 3                                   13                                  13
# 4                                   13                                  13
# ..                                 ...                                 ...
# 75                                  30                                  30
# 76                                  30                                  30
# 77                                  30                                  30
# 78                                  30                                  30
# 79                                  30                                  30
#
#     Vector_Initialized_get()  Vector_Initialized_delete()
# 0                         11                           11
# 1                         12                           12
# 2                         12                           12
# 3                         13                           13
# 4                         13                           13
# ..                       ...                          ...
# 75                        30                           30
# 76                        30                           30
# 77                        30                           30
# 78                        30                           30
# 79                        30                           30
#
# [80 rows x 31 columns]

# %%
df_memory.iloc[0:38].plot(figsize=(10, 10), x="NumberOfElements", 
        y=[
            "ArrayList_insert()", 
            # "ArrayList_insertAt()", 
            # "ArrayList_searchMethod1()",
            # "ArrayList_searchMethod2()",
            # "ArrayList_get()",
            # "ArrayList_delete()",

            "ArrayList_Initialized_insert()", 
            # "ArrayList_Initialized_insertAt()", 
            # "ArrayList_Initialized_searchMethod1()",
            # "ArrayList_Initialized_searchMethod2()",
            # "ArrayList_Initialized_get()",
            # "ArrayList_Initialized_delete()",
            
            "LinkedList_insert()", 
            # "LinkedList_insertAt()", 
            # "LinkedList_searchMethod1()",
            # "LinkedList_searchMethod2()",
            # "LinkedList_get()",
            # "LinkedList_delete()",
            
            "Vector_insert()", 
            # "Vector_insertAt()", 
            # "Vector_searchMethod1()",
            # "Vector_searchMethod2()",
            # "Vector_get()",
            # "Vector_delete()",

            "Vector_Initialized_insert()", 
            # "Vector_Initialized_insertAt()", 
            # "Vector_Initialized_searchMethod1()",
            # "Vector_Initialized_searchMethod2()",
            # "Vector_Initialized_get()",
            # "Vector_Initialized_delete()"
           ]
        )
# Out:
# <AxesSubplot:xlabel='NumberOfElements'>
