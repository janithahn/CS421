# %%
import pandas as pd
import seaborn as sns

# %%
pd.set_option("display.max.columns", None)
df_runtime = pd.read_csv('./data/runtime_10trials_80steps.csv')

# %%
df_runtime
# Out:
#     NumberOfIntegers          DataStructure  insert()  insertAt()  contains()  \
# 0             100000              ArrayList         3           3           3
# 1             100000  ArrayList_Initialized        11          11          11
# 2             100000             LinkedList         5           5           5
# 3             100000                 Vector         4           4           4
# 4             100000      VectorInitialized        11          11          11
# ..               ...                    ...       ...         ...         ...
# 95           1050000              ArrayList        28          28          28
# 96           1050000  ArrayList_Initialized        31          31          31
# 97           1050000             LinkedList        47          47          47
# 98           1050000                 Vector        29          29          29
# 99           1050000      VectorInitialized        31          31          31
#
#     indexOf()  get()  delete()
# 0           3      3         3
# 1          11     11        11
# 2           5      5         5
# 3           4      4         4
# 4          11     11        11
# ..        ...    ...       ...
# 95         28     28        28
# 96         31     31        31
# 97         47     47        47
# 98         29     29        29
# 99         31     31        31
#
# [100 rows x 8 columns]

# %%
df_runtime.iloc[0:38].plot(figsize=(8, 8), x="NumberOfIntegers", 
        y=[
            "ArrayList_insert()", 
            # "ArrayList_insertAt()", 
            # "ArrayList_searchMethod1()",
            # "ArrayList_searchMethod2()",
            # "ArrayList_get()",
            # "ArrayList_delete()",

            "ArrayList_Initialized_insert()", 
            # "ArrayList_Initialized_insertAt()", 
            # "ArrayList_Initialized_searchMethod1()",
            # "ArrayList_Initialized_searchMethod2()",
            # "ArrayList_Initialized_get()",
            # "ArrayList_Initialized_delete()",
            
            # "LinkedList_insert()", 
            # "LinkedList_insertAt()", 
            # "LinkedList_searchMethod1()",
            # "LinkedList_searchMethod2()",
            # "LinkedList_get()",
            # "LinkedList_delete()",
            
            # "Vector_insert()", 
            # "Vector_insertAt()", 
            # "Vector_searchMethod1()",
            # "Vector_searchMethod2()",
            # "Vector_get()",
            # "Vector_delete()"

            # "Vector_insert()", 
            # "Vector_Initialized_insertAt()", 
            # "Vector_Initialized_searchMethod1()",
            # "Vector_Initialized_searchMethod2()",
            # "Vector_Initialized_get()",
            # "Vector_Initialized_delete()"
           ]
        )
# Out:
# <AxesSubplot:xlabel='NumberOfIntegers'>

# %%
df_runtime.count()
# Out:
# NumberOfIntegers                         80
# ArrayList_insert()                       80
# ArrayList_insertAt()                     80
# ArrayList_searchMethod1()                80
# ArrayList_searchMethod2()                80
# ArrayList_get()                          80
# ArrayList_delete()                       80
# ArrayList_Initialized_insert()           80
# ArrayList_Initialized_insertAt()         80
# ArrayList_Initialized_searchMethod1()    80
# ArrayList_Initialized_searchMethod2()    80
# ArrayList_Initialized_get()              80
# ArrayList_Initialized_delete()           80
# LinkedList_insert()                      80
# LinkedList_insertAt()                    80
# LinkedList_searchMethod1()               80
# LinkedList_searchMethod2()               80
# LinkedList_get()                         80
# LinkedList_delete()                      80
# Vector_insert()                          80
# Vector_insertAt()                        80
# Vector_searchMethod1()                   80
# Vector_searchMethod2()                   80
# Vector_get()                             80
# Vector_delete()                          80
# Vector_Initialized_insert()              80
# Vector_Initialized_insertAt()            80
# Vector_Initialized_searchMethod1()       80
# Vector_Initialized_searchMethod2()       80
# Vector_Initialized_get()                 80
# Vector_Initialized_delete()              80
# dtype: int64

# %%
df_runtime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   NumberOfIntegers                       80 non-null     int64
#  1   ArrayList_insert()                     80 non-null     float64
#  2   ArrayList_insertAt()                   80 non-null     float64
#  3   ArrayList_searchMethod1()              80 non-null     float64
#  4   ArrayList_searchMethod2()              80 non-null     float64
#  5   ArrayList_get()                        80 non-null     float64
#  6   ArrayList_delete()                     80 non-null     float64
#  7   ArrayList_Initialized_insert()         80 non-null     float64
#  8   ArrayList_Initialized_insertAt()       80 non-null     float64
#  9   ArrayList_Initialized_searchMethod1()  80 non-null     float64
#  10  ArrayList_Initialized_searchMethod2()  80 non-null     float64
#  11  ArrayList_Initialized_get()            80 non-null     float64
#  12  ArrayList_Initialized_delete()         80 non-null     float64
#  13  LinkedList_insert()                    80 non-null     float64
#  14  LinkedList_insertAt()                  80 non-null     float64
#  15  LinkedList_searchMethod1()             80 non-null     float64
#  16  LinkedList_searchMethod2()             80 non-null     float64
#  17  LinkedList_get()                       80 non-null     float64
#  18  LinkedList_delete()                    80 non-null     float64
#  19  Vector_insert()                        80 non-null     float64
#  20  Vector_insertAt()                      80 non-null     float64
#  21  Vector_searchMethod1()                 80 non-null     float64
#  22  Vector_searchMethod2()                 80 non-null     float64
#  23  Vector_get()                           80 non-null     float64
#  24  Vector_delete()                        80 non-null     float64
#  25  Vector_Initialized_insert()            80 non-null     float64
#  26  Vector_Initialized_insertAt()          80 non-null     float64
#  27  Vector_Initialized_searchMethod1()     80 non-null     float64
#  28  Vector_Initialized_searchMethod2()     80 non-null     float64
#  29  Vector_Initialized_get()               80 non-null     float64
#  30  Vector_Initialized_delete()            80 non-null     float64
# dtypes: float64(30), int64(1)
# memory usage: 19.5 KB

# %%
df_runtime.describe()
# Out:
#        NumberOfIntegers  ArrayList_insert()  ArrayList_insertAt()  \
# count      8.000000e+01           80.000000             80.000000
# mean       1.087500e+06           12.519625            684.609125
# std        5.809475e+05            6.725629            384.721853
# min        1.000000e+05            1.040000              5.780000
# 25%        5.937500e+05            7.557500            308.422500
# 50%        1.087500e+06           11.530000            963.485000
# 75%        1.581250e+06           14.485000            987.812500
# max        2.075000e+06           31.760000           1026.650000
#
#        ArrayList_searchMethod1()  ArrayList_searchMethod2()  ArrayList_get()  \
# count                   80.00000                  80.000000        80.000000
# mean                    21.20550                  21.044000         0.009625
# std                     11.93355                  11.731452         0.016338
# min                      0.39000                   0.390000         0.000000
# 25%                      9.20500                   9.287500         0.000000
# 50%                     28.81500                  28.575000         0.010000
# 75%                     30.52750                  30.050000         0.010000
# max                     34.92000                  32.820000         0.100000
#
#        ArrayList_delete()  ArrayList_Initialized_insert()  \
# count           80.000000                       80.000000
# mean           689.114000                        7.587750
# std            386.953083                        2.723053
# min              5.810000                        1.000000
# 25%            310.842500                        6.430000
# 50%            971.415000                        7.935000
# 75%            993.505000                        9.337500
# max           1030.880000                       12.880000
#
#        ArrayList_Initialized_insertAt()  \
# count                           80.0000
# mean                           685.5335
# std                            385.0763
# min                              5.1800
# 25%                            306.6525
# 50%                            967.0350
# 75%                            988.4325
# max                           1029.8700
#
#        ArrayList_Initialized_searchMethod1()  \
# count                              80.000000
# mean                               21.183625
# std                                11.927357
# min                                 0.260000
# 25%                                 9.097500
# 50%                                29.230000
# 75%                                30.592500
# max                                33.170000
#
#        ArrayList_Initialized_searchMethod2()  ArrayList_Initialized_get()  \
# count                              80.000000                    80.000000
# mean                               21.126750                     0.009125
# std                                11.785678                     0.014942
# min                                 0.260000                     0.000000
# 25%                                 9.162500                     0.000000
# 50%                                28.960000                     0.010000
# 75%                                30.215000                     0.010000
# max                                33.440000                     0.100000
#
#        ArrayList_Initialized_delete()  LinkedList_insert()  \
# count                       80.000000            80.000000
# mean                       689.138875            28.947250
# std                        386.892408            21.400911
# min                          5.320000             0.570000
# 25%                        309.337500            10.367500
# 50%                        969.275000            23.445000
# 75%                        996.627500            47.765000
# max                       1032.160000            76.420000
#
#        LinkedList_insertAt()  LinkedList_searchMethod1()  \
# count              80.000000                   80.000000
# mean               43.982125                   65.828750
# std                24.081154                   36.481586
# min                 0.700000                    1.050000
# 25%                19.780000                   29.077500
# 50%                60.630000                   90.870000
# 75%                63.332500                   94.237500
# max                67.430000                  101.160000
#
#        LinkedList_searchMethod2()  LinkedList_get()  LinkedList_delete()  \
# count                   80.000000         80.000000            80.000000
# mean                    66.141500         42.987250             0.039500
# std                     36.639386         23.593647             0.015002
# min                      0.850000          0.670000             0.010000
# 25%                     29.362500         19.345000             0.030000
# 50%                     91.110000         59.750000             0.040000
# 75%                     95.750000         61.640000             0.050000
# max                    102.650000         67.820000             0.090000
#
#        Vector_insert()  Vector_insertAt()  Vector_searchMethod1()  \
# count        80.000000          80.000000               80.000000
# mean         10.322750         686.326375               21.852500
# std           5.917916         384.704778               12.284472
# min           0.880000           5.850000                0.400000
# 25%           7.377500         307.237500                9.477500
# 50%           9.540000         958.490000               29.730000
# 75%          10.250000         985.662500               31.067500
# max          27.740000        1039.750000               36.140000
#
#        Vector_searchMethod2()  Vector_get()  Vector_delete()  \
# count               80.000000       80.0000        80.000000
# mean                21.836375        0.0205       689.179000
# std                 12.197790        0.0155       386.238758
# min                  0.400000        0.0000         5.940000
# 25%                  9.615000        0.0200       309.810000
# 50%                 29.755000        0.0200       967.005000
# 75%                 31.290000        0.0200       991.080000
# max                 34.540000        0.1100      1032.110000
#
#        Vector_Initialized_insert()  Vector_Initialized_insertAt()  \
# count                    80.000000                      80.000000
# mean                      6.973250                     686.106125
# std                       2.547042                     385.185514
# min                       0.760000                       5.130000
# 25%                       5.372500                     307.775000
# 50%                       8.045000                     965.615000
# 75%                       8.682500                     988.665000
# max                      10.160000                    1032.620000
#
#        Vector_Initialized_searchMethod1()  Vector_Initialized_searchMethod2()  \
# count                           80.000000                           80.000000
# mean                            21.873250                           22.013375
# std                             12.298552                           12.386807
# min                              0.260000                            0.260000
# 25%                              9.427500                            9.542500
# 50%                             30.100000                           30.060000
# 75%                             31.482500                           31.602500
# max                             35.130000                           38.250000
#
#        Vector_Initialized_get()  Vector_Initialized_delete()
# count                 80.000000                    80.000000
# mean                   0.019375                   690.584000
# std                    0.011401                   387.694494
# min                    0.000000                     5.180000
# 25%                    0.020000                   309.102500
# 50%                    0.020000                   972.210000
# 75%                    0.020000                   998.605000
# max                    0.090000                  1038.930000

# %%
df_runtime['ArrayList_insert()'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.heatmap(df_runtime.isnull(), yticklabels=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df_runtime, linewidth=1)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split

# %%
print(df_runtime.shape)
# Out:
# (80, 31)

# %%
num_of_classes = len(df_runtime.Class.unique())
print(num_of_classes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_41/2860970978.py in <module>
# ----> 1 num_of_classes = len(df_runtime.Class.unique())
#       2 print(num_of_classes)
#
# ~/anaconda3/envs/ml/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Class'
